# %%
import torch

# %%
torch.version.cuda
# Out:
# '10.1.243'

# %%
torch.cuda.is_available()
# Out:
# True

# %%
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
if device==torch.device("cuda"):
    print("Using device:", torch.cuda.get_device_name(0))
else:
    print("Using device:", device)
# Out:
# Using device: Tesla K80

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount= True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
dataset = 'drive/My Drive/dataset/'

# %%
project = 'drive/My Drive/lane-detection-master/'

# %%
# !python "/content/drive/My Drive/lane-detection-master/train.py"
# Out:
# Using device: Tesla P100-PCIE-16GB
# Downloading: "https://download.pytorch.org/models/vgg16_bn-6c64b313.pth" to /root/.cache/torch/checkpoints/vgg16_bn-6c64b313.pth
# 100% 528M/528M [00:10<00:00, 54.9MB/s]
# Instantiating Segnet encoder with max unpooling
# Output min -18.22343635559082 Output (softmax-ed) sum: 326888.0 Output max: 18.425064086914062
# Targets sum: tensor(20121., device='cuda:0')
# Base acc:0.95208740234375 - base prec: 0.5432287454605103- base recall: 0.8522531390190125- base f1: 0.6507089734077454
# Epoch: [0][  0/363]	BatchTime 29.116 (29.116)	Data 28.439 (28.439)	Loss 3.7446e-01 (3.7446e-01)	Acc 0.9521 (0.9521)	F1 0.6507 (0.6507)	Prec 0.5432 (0.5432)	Recall 0.8523 (0.8523)
#
#
# Output min -13.577803611755371 Output (softmax-ed) sum: 326606.0 Output max: 13.921333312988281
# Targets sum: tensor(22128., device='cuda:0')
# Base acc:0.8883209228515625 - base prec: 0.38301539421081543- base recall: 0.9205150604248047- base f1: 0.525844395160675
# ...

# %%
# !python "/content/drive/My Drive/lane-detection-master/test.py"
# Out:
# Using device: Tesla P100-PCIE-16GB
# Loading stored model
# Instantiating Segnet encoder with max unpooling
# Model loaded
# Test: [ 0/37]	Time 10.814 (10.814)	Loss 5.5011e-01 (5.5011e-01)	Acc 0.9484 (0.9484)	F1 0.6549 (0.6549)	Prec 0.5519 (0.5519)	Recall 0.8436 (0.8436)
# Test: [ 1/37]	Time  1.443 ( 6.129)	Loss 6.2345e-01 (5.8678e-01)	Acc 0.9481 (0.9482)	F1 0.6525 (0.6537)	Prec 0.5510 (0.5514)	Recall 0.8401 (0.8419)
# Test: [ 2/37]	Time  8.195 ( 6.818)	Loss 5.4330e-01 (5.7229e-01)	Acc 0.9499 (0.9488)	F1 0.6609 (0.6561)	Prec 0.5587 (0.5538)	Recall 0.8466 (0.8434)
# Test: [ 3/37]	Time  1.451 ( 5.476)	Loss 5.2418e-01 (5.6026e-01)	Acc 0.9492 (0.9489)	F1 0.6610 (0.6573)	Prec 0.5581 (0.5549)	Recall 0.8499 (0.8450)
# Test: [ 4/37]	Time  8.157 ( 6.012)	Loss 5.1622e-01 (5.5145e-01)	Acc 0.9470 (0.9485)	F1 0.6436 (0.6546)	Prec 0.5390 (0.5517)	Recall 0.8407 (0.8442)
# ...

# %%
# !python "/content/drive/My Drive/lane-detection-master/test.py"
# Out:
# Using device: Tesla P100-PCIE-16GB
# Loading stored model
# Instantiating Segnet encoder with max unpooling
# Model loaded
# Test: [ 0/37]	Time 11.017 (11.017)	Loss 6.3469e-02 (6.3469e-02)	Acc 0.9277 (0.9277)	F1 0.6031 (0.6031)	Prec 0.4637 (0.4637)	Recall 0.9117 (0.9117)
# Test: [ 1/37]	Time  1.378 ( 6.198)	Loss 6.1291e-02 (6.2380e-02)	Acc 0.9294 (0.9285)	F1 0.6144 (0.6087)	Prec 0.4741 (0.4689)	Recall 0.9205 (0.9161)
# Test: [ 2/37]	Time  8.146 ( 6.847)	Loss 6.2088e-02 (6.2282e-02)	Acc 0.9291 (0.9287)	F1 0.6179 (0.6118)	Prec 0.4787 (0.4722)	Recall 0.9193 (0.9172)
# Test: [ 3/37]	Time  1.449 ( 5.497)	Loss 6.6143e-02 (6.3248e-02)	Acc 0.9270 (0.9283)	F1 0.6204 (0.6139)	Prec 0.4795 (0.4740)	Recall 0.9293 (0.9202)
# Test: [ 4/37]	Time  8.287 ( 6.055)	Loss 6.3208e-02 (6.3240e-02)	Acc 0.9270 (0.9280)	F1 0.6184 (0.6148)	Prec 0.4775 (0.4747)	Recall 0.9290 (0.9220)
# ...

# %%
# !python "/content/drive/My Drive/lane-detection-master/visual_evaluation.py"
# Out:
# Using device: cpu
# Loading stored model
# Instantiating Segnet encoder with max unpooling
# Model loaded
# Loss: tensor(0.0611)
# Output max: 1.0 Output mean 0.149383544921875
# Pixel lane points: 4442.0 9790.0
# Loss: tensor(0.0556)
# Output max: 1.0 Output mean 0.1376953125
# Pixel lane points: 4444.0 9024.0
# Loss: tensor(0.0570)
# Output max: 1.0 Output mean 0.1205291748046875
# Pixel lane points: 3678.0 7899.0
# Traceback (most recent call last):
#   File "/content/drive/My Drive/lane-detection-master/visual_evaluation.py", line 34, in <module>
#     for batchno, (frames, targets) in enumerate(tu_dataloader):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 346, in __next__
#     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/_utils/fetch.py", line 44, in fetch
#     data = [self.dataset[idx] for idx in possibly_batched_index]
# ...

# %%
# !python "/content/drive/My Drive/lane-detection-master/utils/make_video_sample.py"
# Out:
# /content/drive/My Drive/dataset/clips/0601
# 0 1494452385593783358
# /content/drive/My Drive/dataset/clips/0601/1494452385593783358/1.jpg
# /content/drive/My Drive/dataset/clips/0601/1494452385593783358/2.jpg
# /content/drive/My Drive/dataset/clips/0601/1494452385593783358/3.jpg
# /content/drive/My Drive/dataset/clips/0601/1494452385593783358/4.jpg
# /content/drive/My Drive/dataset/clips/0601/1494452385593783358/5.jpg
# /content/drive/My Drive/dataset/clips/0601/1494452385593783358/6.jpg
# /content/drive/My Drive/dataset/clips/0601/1494452385593783358/7.jpg
# /content/drive/My Drive/dataset/clips/0601/1494452385593783358/8.jpg
# /content/drive/My Drive/dataset/clips/0601/1494452385593783358/9.jpg
# /content/drive/My Drive/dataset/clips/0601/1494452385593783358/10.jpg
# /content/drive/My Drive/dataset/clips/0601/1494452385593783358/11.jpg
# /content/drive/My Drive/dataset/clips/0601/1494452385593783358/12.jpg
# /content/drive/My Drive/dataset/clips/0601/1494452385593783358/13.jpg
# ...

# %%
# !python "/content/drive/My Drive/lane-detection-master/video-comparison.py"
# Out:
# Using device: Tesla P100-PCIE-16GB
# Instantiating Segnet encoder with max unpooling
# Loading model..
# Using images at original scale
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-38-668d714d7f55> in <module>()
# ----> 1 get_ipython().system('python "/content/drive/My Drive/lane-detection-master/video-comparison.py"')
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_shell.py in system(self, *args, **kwargs)
#      94       kwargs.update({'also_return_output': True})
#      95
# ---> 96     output = _system_commands._system_compat(self, *args, **kwargs)  # pylint:disable=protected-access
#      97
#      98     if pip_warn:
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_system_commands.py in _system_compat(shell, cmd, also_return_output)
#     436   # stack.
#     437   result = _run_command(
# ...

# %%
# !python "/content/drive/My Drive/lane-detection-master/train.py"
# Out:
# Using device: Tesla K80
# Downloading: "https://download.pytorch.org/models/vgg16_bn-6c64b313.pth" to /root/.cache/torch/checkpoints/vgg16_bn-6c64b313.pth
# 100% 528M/528M [00:05<00:00, 102MB/s]
# Instantiating Segnet encoder with max unpooling
# Output min -16.914966583251953 Output (softmax-ed) sum: 327065.0 Output max: 16.954898834228516
# Targets sum: tensor(20381., device='cuda:0')
# Base acc:0.9657806754112244 - base prec: 0.5828981399536133- base recall: 0.8832470178604126- base f1: 0.6938508152961731
# Epoch: [0][  0/363]	BatchTime 44.046 (44.046)	Data 41.533 (41.533)	Loss 3.4556e-02 (3.4556e-02)	Acc 0.9658 (0.9658)	F1 0.6939 (0.6939)	Prec 0.5829 (0.5829)	Recall 0.8832 (0.8832)
# Output min -16.20083236694336 Output (softmax-ed) sum: 326585.0 Output max: 16.830238342285156
# Targets sum: tensor(21429., device='cuda:0')
# Base acc:0.8738922476768494 - base prec: 0.35275760293006897- base recall: 0.9013200998306274- base f1: 0.4899819493293762
# ...

# %%
# !python "/content/drive/My Drive/lane-detection-master/test.py"
# Out:
# Using device: Tesla P100-PCIE-16GB
# Loading stored model
# Instantiating Segnet encoder with max unpooling
# Model loaded
# Test: [ 0/37]	Time 330.661 (330.661)	Loss 7.6529e-02 (7.6529e-02)	Acc 0.9248 (0.9248)	F1 0.6125 (0.6125)	Prec 0.4740 (0.4740)	Recall 0.9222 (0.9222)
# Test: [ 1/37]	Time 35.259 (182.960)	Loss 8.3120e-02 (7.9824e-02)	Acc 0.9197 (0.9223)	F1 0.6071 (0.6098)	Prec 0.4667 (0.4703)	Recall 0.9289 (0.9256)
# Test: [ 2/37]	Time 310.972 (225.631)	Loss 8.1336e-02 (8.0328e-02)	Acc 0.9198 (0.9215)	F1 0.6072 (0.6089)	Prec 0.4688 (0.4698)	Recall 0.9225 (0.9245)
# Test: [ 3/37]	Time  2.991 (169.971)	Loss 8.7188e-02 (8.2043e-02)	Acc 0.9186 (0.9208)	F1 0.5983 (0.6062)	Prec 0.4613 (0.4677)	Recall 0.9155 (0.9223)
# Test: [ 4/37]	Time 419.362 (219.849)	Loss 7.5564e-02 (8.0747e-02)	Acc 0.9227 (0.9211)	F1 0.6061 (0.6062)	Prec 0.4678 (0.4677)	Recall 0.9192 (0.9217)
#
# ...

# %%
# !python "/content/drive/My Drive/lane-detection-master/train.py"
# Out:
# Using device: Tesla K80
# Instantiating Segnet encoder with max unpooling
# Output min -2.3735191822052 Output (softmax-ed) sum: 453895.0 Output max: 3.043397903442383
# Targets sum: tensor(21720., device='cuda:0')
# Base acc:0.5418182611465454 - base prec: 0.06660584360361099- base recall: 0.43174466490745544- base f1: 0.11317689716815948
# Epoch: [0][  0/363]	BatchTime 25.626 (25.626)	Data 23.203 (23.203)	Loss 9.3343e-01 (9.3343e-01)	Acc 0.5418 (0.5418)	F1 0.1132 (0.1132)	Prec 0.0666 (0.0666)	Recall 0.4317 (0.4317)
# Output min -5.812185764312744 Output (softmax-ed) sum: 477009.0 Output max: 5.404242992401123
# Targets sum: tensor(22159., device='cuda:0')
# Base acc:0.067901611328125 - base prec: 0.06762707233428955- base recall: 0.9264553189277649- base f1: 0.12530584633350372
# Epoch: [0][ 16/363]	BatchTime 17.921 ( 6.507)	Data 15.647 ( 4.219)	Loss 3.6396e-01 (5.3164e-01)	Acc 0.0679 (0.1198)	F1 0.1253 (0.1214)	Prec 0.0676 (0.0660)	Recall 0.9265 (0.8767)
# ...

# %%
# !python "/content/drive/My Drive/lane-detection-master/train.py"
# Out:
# Using device: Tesla K80
# Instantiating Segnet encoder with max unpooling
# Output min -18.270002365112305 Output (softmax-ed) sum: 326766.0 Output max: 18.103992462158203
# Targets sum: tensor(21352., device='cuda:0')
# Base acc:0.940399169921875 - base prec: 0.5243729948997498- base recall: 0.8383952975273132- base f1: 0.6297019124031067
# Epoch: [0][  0/363]	BatchTime  4.739 ( 4.739)	Data  2.376 ( 2.376)	Loss 6.1332e-01 (6.1332e-01)	Acc 0.9404 (0.9404)	F1 0.6297 (0.6297)	Prec 0.5244 (0.5244)	Recall 0.8384 (0.8384)
# Output min -12.971625328063965 Output (softmax-ed) sum: 326469.0 Output max: 13.273027420043945
# Targets sum: tensor(22363., device='cuda:0')
# Base acc:0.9026947021484375 - base prec: 0.4191861152648926- base recall: 0.919324517250061- base f1: 0.5637995004653931
# Epoch: [0][ 16/363]	BatchTime  2.264 ( 2.398)	Data  0.007 ( 0.147)	Loss 1.1760e-01 (2.2489e-01)	Acc 0.9027 (0.9120)	F1 0.5638 (0.5766)	Prec 0.4192 (0.4428)	Recall 0.9193 (0.8956)
# ...

# %%
# !python "/content/drive/My Drive/lane-detection-master/test.py"
# Out:
# Using device: Tesla K80
# Loading stored model
# Instantiating Segnet encoder with max unpooling
# Model loaded
# Test: [ 0/37]	Time 125.356 (125.356)	Loss 8.3411e-01 (8.3411e-01)	Acc 0.9405 (0.9405)	F1 0.6007 (0.6007)	Prec 0.5057 (0.5057)	Recall 0.7903 (0.7903)
# Test: [ 1/37]	Time  4.499 (64.927)	Loss 7.8130e-01 (8.0771e-01)	Acc 0.9429 (0.9417)	F1 0.6331 (0.6169)	Prec 0.5401 (0.5229)	Recall 0.8084 (0.7993)
# Test: [ 2/37]	Time 79.864 (69.906)	Loss 5.0886e-01 (7.0809e-01)	Acc 0.9487 (0.9440)	F1 0.6469 (0.6269)	Prec 0.5469 (0.5309)	Recall 0.8355 (0.8114)
# Test: [ 3/37]	Time  8.996 (54.679)	Loss 6.7805e-01 (7.0058e-01)	Acc 0.9436 (0.9439)	F1 0.6237 (0.6261)	Prec 0.5253 (0.5295)	Recall 0.8097 (0.8110)
# Test: [ 4/37]	Time 79.376 (59.618)	Loss 5.5545e-01 (6.7156e-01)	Acc 0.9469 (0.9445)	F1 0.6397 (0.6288)	Prec 0.5386 (0.5313)	Recall 0.8262 (0.8140)
# ...

# %%
# !python "/content/drive/My Drive/lane-detection-master/test.py"
# Out:
# Using device: Tesla K80
# Loading stored model
# Downloading: "https://download.pytorch.org/models/vgg16_bn-6c64b313.pth" to /root/.cache/torch/checkpoints/vgg16_bn-6c64b313.pth
# 100% 528M/528M [00:08<00:00, 61.5MB/s]
# Instantiating Segnet encoder with max unpooling
# Model loaded
#
# Test: [ 0/16]	Time 260.394 (260.394)	Loss 1.5454e+00 (1.5454e+00)	Acc 0.9276 (0.9276)	F1 0.5420 (0.5420)	Prec 0.4569 (0.4569)	Recall 0.7217 (0.7217)
# Test: [ 1/16]	Time  4.546 (132.470)	Loss 1.4639e+00 (1.5046e+00)	Acc 0.9288 (0.9282)	F1 0.5536 (0.5478)	Prec 0.4654 (0.4611)	Recall 0.7342 (0.7280)
# Test: [ 2/16]	Time 225.692 (163.544)	Loss 1.5902e+00 (1.5332e+00)	Acc 0.9277 (0.9280)	F1 0.5372 (0.5442)	Prec 0.4547 (0.4590)	Recall 0.7124 (0.7228)
# Test: [ 3/16]	Time  4.554 (123.796)	Loss 1.4071e+00 (1.5016e+00)	Acc 0.9305 (0.9286)	F1 0.5630 (0.5489)	Prec 0.4769 (0.4635)	Recall 0.7395 (0.7269)
# ...

# %% [markdown]
# n_frames = 5

# %%
# !python "/content/drive/My Drive/lane-detection-master/train.py"
# Out:
# Using device: Tesla K80
# Downloading: "https://download.pytorch.org/models/vgg16_bn-6c64b313.pth" to /root/.cache/torch/checkpoints/vgg16_bn-6c64b313.pth
# 100% 528M/528M [00:10<00:00, 51.1MB/s]
# Instantiating Segnet encoder with max unpooling
# Output min -21.08457374572754 Output (softmax-ed) sum: 326866.0 Output max: 20.41422462463379
# Targets sum: tensor(23242., device='cuda:0')
# Base acc:0.9483276605606079 - base prec: 0.5574767589569092- base recall: 0.8372158408164978- base f1: 0.6549099087715149
# Epoch: [0][  0/363]	BatchTime 38.745 (38.745)	Data 36.321 (36.321)	Loss 4.5403e-01 (4.5403e-01)	Acc 0.9483 (0.9483)	F1 0.6549 (0.6549)	Prec 0.5575 (0.5575)	Recall 0.8372 (0.8372)
#
# Output min -14.494148254394531 Output (softmax-ed) sum: 326421.0 Output max: 14.8635835647583
# Targets sum: tensor(22230., device='cuda:0')
# Base acc:0.8776947259902954 - base prec: 0.3857409656047821- base recall: 0.9323469400405884- base f1: 0.5278615355491638
# ...

# %%
# !python "/content/drive/My Drive/lane-detection-master/test.py"
# Out:
# Using device: Tesla K80
# Loading stored model
# Instantiating Segnet encoder with max unpooling
# Model loaded
# Test: [ 0/16]	Time 17.048 (17.048)	Loss 6.3022e-02 (6.3022e-02)	Acc 0.9285 (0.9285)	F1 0.6164 (0.6164)	Prec 0.4760 (0.4760)	Recall 0.9224 (0.9224)
# Test: [ 1/16]	Time  4.472 (10.760)	Loss 6.0715e-02 (6.1868e-02)	Acc 0.9315 (0.9300)	F1 0.6157 (0.6160)	Prec 0.4766 (0.4763)	Recall 0.9163 (0.9194)
# Test: [ 2/16]	Time  9.863 (10.461)	Loss 5.9023e-02 (6.0920e-02)	Acc 0.9309 (0.9303)	F1 0.6284 (0.6202)	Prec 0.4876 (0.4801)	Recall 0.9300 (0.9229)
# Test: [ 3/16]	Time  4.509 ( 8.973)	Loss 6.1676e-02 (6.1109e-02)	Acc 0.9295 (0.9301)	F1 0.6192 (0.6199)	Prec 0.4785 (0.4797)	Recall 0.9259 (0.9236)
# Test: [ 4/16]	Time  9.321 ( 9.043)	Loss 6.0501e-02 (6.0987e-02)	Acc 0.9329 (0.9307)	F1 0.6264 (0.6212)	Prec 0.4853 (0.4808)	Recall 0.9294 (0.9248)
# ...

# %% [markdown]
# n_frames = 3

# %%
# !python "/content/drive/My Drive/lane-detection-master/train.py"
# Out:
# Using device: Tesla K80
# Instantiating Segnet encoder with max unpooling
# Output min -18.690073013305664 Output (softmax-ed) sum: 326952.0 Output max: 18.950281143188477
# Targets sum: tensor(21254., device='cuda:0')
# Base acc:0.951617419719696 - base prec: 0.5430279970169067- base recall: 0.829198956489563- base f1: 0.6466483473777771
# Epoch: [0][  0/363]	BatchTime  3.263 ( 3.263)	Data  1.600 ( 1.600)	Loss 4.7835e-01 (4.7835e-01)	Acc 0.9516 (0.9516)	F1 0.6466 (0.6466)	Prec 0.5430 (0.5430)	Recall 0.8292 (0.8292)
# Output min -13.292959213256836 Output (softmax-ed) sum: 326525.0 Output max: 13.905116081237793
# Targets sum: tensor(20918., device='cuda:0')
# Base acc:0.8929168581962585 - base prec: 0.37677499651908875- base recall: 0.8915319442749023- base f1: 0.516185462474823
# Epoch: [0][ 16/363]	BatchTime  1.474 ( 1.578)	Data  0.005 ( 0.100)	Loss 9.4816e-02 (2.3257e-01)	Acc 0.8929 (0.9038)	F1 0.5162 (0.5556)	Prec 0.3768 (0.4232)	Recall 0.8915 (0.8892)
# ...

# %% [markdown]
# n_frames = 8

# %%
# !python "/content/drive/My Drive/lane-detection-master/train.py"
# Out:
# Using device: Tesla K80
# Instantiating Segnet encoder with max unpooling
# Output min -19.336565017700195 Output (softmax-ed) sum: 326877.0 Output max: 19.230525970458984
# Targets sum: tensor(20547., device='cuda:0')
# Base acc:0.9466491937637329 - base prec: 0.530488133430481- base recall: 0.8107126355171204- base f1: 0.6296030879020691
# Epoch: [0][  0/363]	BatchTime 22.392 (22.392)	Data 18.865 (18.865)	Loss 5.8913e-01 (5.8913e-01)	Acc 0.9466 (0.9466)	F1 0.6296 (0.6296)	Prec 0.5305 (0.5305)	Recall 0.8107 (0.8107)
# Output min -13.887510299682617 Output (softmax-ed) sum: 326512.0 Output max: 14.308869361877441
# Targets sum: tensor(21268., device='cuda:0')
# Base acc:0.8694732785224915 - base prec: 0.35054096579551697- base recall: 0.9169911742210388- base f1: 0.49197131395339966
# Epoch: [0][ 16/363]	BatchTime  4.806 ( 6.134)	Data  1.418 ( 2.747)	Loss 1.3883e-01 (2.2933e-01)	Acc 0.8695 (0.9096)	F1 0.4920 (0.5711)	Prec 0.3505 (0.4391)	Recall 0.9170 (0.8939)
# ...

# %%
# !python "/content/drive/My Drive/lane-detection-master/test.py"
# Out:
# Using device: Tesla K80
# Loading stored model
# Instantiating Segnet encoder with max unpooling
# Model loaded
# Test: [ 0/16]	Time 26.008 (26.008)	Loss 7.3852e-02 (7.3852e-02)	Acc 0.9192 (0.9192)	F1 0.5880 (0.5880)	Prec 0.4450 (0.4450)	Recall 0.9197 (0.9197)
# Test: [ 1/16]	Time  6.786 (16.397)	Loss 6.7037e-02 (7.0444e-02)	Acc 0.9240 (0.9216)	F1 0.6076 (0.5978)	Prec 0.4644 (0.4547)	Recall 0.9285 (0.9241)
# Test: [ 2/16]	Time 15.293 (16.029)	Loss 6.6549e-02 (6.9146e-02)	Acc 0.9244 (0.9225)	F1 0.5979 (0.5978)	Prec 0.4548 (0.4548)	Recall 0.9215 (0.9233)
# Test: [ 3/16]	Time  6.883 (13.742)	Loss 6.4722e-02 (6.8040e-02)	Acc 0.9259 (0.9234)	F1 0.5970 (0.5976)	Prec 0.4551 (0.4549)	Recall 0.9171 (0.9217)
# Test: [ 4/16]	Time 14.652 (13.924)	Loss 7.0498e-02 (6.8531e-02)	Acc 0.9204 (0.9228)	F1 0.5921 (0.5965)	Prec 0.4496 (0.4538)	Recall 0.9223 (0.9218)
# ...
